# %% [markdown]
# <a href="https://colab.research.google.com/github/ziad-90/learn2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##mardown

# %%
print("hello world")
# Out:
# hello world
